# %% [markdown]
# <a href="https://colab.research.google.com/github/manu001223/NLP-533/blob/main/Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
text ="Hi i am Manoj N."
output1 = word_tokenize(text)
print(output1)
# Out:
# ['Hi', 'i', 'am', 'Manoj', 'N', '.']

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
import en_core_web_sm
nlp = en_core_web_sm.load()
doc = nlp("I am Manoj N")
print([(w.text, w.pos_) for w in doc])
# Out:
# [('I', 'PRON'), ('am', 'AUX'), ('Manoj', 'PROPN'), ('N', 'PROPN')]
